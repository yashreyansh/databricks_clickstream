-- %%
GRANT USE CATALOG ON CATALOG workspace TO `<mail>@gmail.com`;


GRANT USE SCHEMA ON SCHEMA workspace.bronze_click TO `<mail>@gmail.com`;
GRANT READ VOLUME, WRITE VOLUME
ON VOLUME workspace.bronze_click.bronze_raw_data
TO `<mail>@gmail.com`;

DROP TABLE IF EXISTS workspace.bronze_click.bronze_raw_data;

DROP TABLE IF EXISTS workspace.silver_click.click_data;
select * from workspace.silver_click.click_data;

select UID, count(*) From  workspace.bronze_click.bronze_raw_data
group by UID having count(*)>1

select * From workspace.bronze_click.bronze_raw_data where uid in ('85772854d652a4368d70265c2e3c0d31')
